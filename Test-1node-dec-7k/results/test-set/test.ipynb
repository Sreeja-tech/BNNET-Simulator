# %%
import os

# %%
# Set the directory where the dataset is located
# data_dir = os.getcwd()  # or the specific path where your dataset is located
# data_dir = os.path.join(data_dir, "results\\dataset-1")

# %%
# data_dir = "C:\\Users\\SREEJA\\BNNetSimulator-main\\testing-dataset-bw-inc\\results\\test-set"

data_dir = "D:\\Sre\\Final\\BNNetSimulator-main-1\\Test-1node-dec-7k\\results\\test-set"

# %%
data_dir
# Out:
# 'D:\\Sre\\Final\\BNNetSimulator-main-1\\Test-1node-dec-7k\\results\\test-set'

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from datanetAPI import DatanetAPI

# %%
tool = DatanetAPI(data_dir)

# %%
for sample in iter(tool):
    print(sample.get_global_delay())
# Out:
# 0.017565
# 0.018033
# 0.017249
# 0.017767
# 0.017795
# 0.017383
# 0.018101
# 0.017413
# 0.017354
# 0.017468
# 0.018069
# 0.017946
# 0.017757
# 0.017623
# 0.017698
# 0.017859
# 0.018103
# 0.0179
# 0.018318
# 0.017323
# 0.017255
# 0.017462
# 0.017419
# 0.01791
# 0.017395
# 0.017863
# 0.017901
# 0.017322
# 0.017271
# 0.017845
# 0.017474
# 0.01747
# 0.01752
# 0.017984
# 0.018201
# 0.017351
# 0.017414
# 0.017514
# 0.017816
# 0.018178
# 0.01755
# 0.017438
# 0.017793
# 0.017964
# 0.01761
# 0.017844
# 0.017675
# 0.018269
# 0.017844
# 0.017451
# 0.017386
# 0.017776
# 0.017886
# 0.017473
# 0.017512
# 0.016654
# 0.017842
# 0.017267
# 0.017892
# 0.017429
# 0.017334
# 0.01769
# 0.017538
# 0.017749
# 0.018557
# 0.018176
# 0.017603
# 0.017389
# 0.018229
# 0.017993
# 0.017752
# 0.017272
# 0.017462
# 0.018397
# 0.017901
# 0.017197
# 0.01733
# 0.018181
# 0.017436
# 0.017386
# 0.017745
# 0.017705
# 0.017587
# 0.017974
# 0.016964
# 0.017444
# 0.017772
# 0.017465
# 0.017874
# 0.017397
# 0.018255
# ...

# %%
delays = []  # Initialize an empty list to store delays

for sample in iter(tool):
    delays.append(sample.get_global_delay())

print(len(delays))  # Print the length of delays
# Out:
# 2100

# %%
for sample in iter(tool):
    print(sample.get_global_packets())
# Out:
# 93.2274
# 105.531
# 100.469
# 95.178
# 94.2253
# 94.6295
# 102.884
# 99.5888
# 94.4197
# 103.607
# 94.8529
# 99.2767
# 99.8454
# 93.9906
# 98.2585
# 100.095
# 97.2104
# 100.584
# 98.1921
# 94.278
# 96.8258
# 107.275
# 100.683
# 102.549
# 106.078
# 91.1509
# 95.955
# 101.015
# 103.157
# 100.093
# 94.1855
# 102.162
# 103.672
# 97.7783
# 101.621
# 101.561
# 102.918
# 103.91
# 93.2778
# 107.03
# 91.727
# 93.2655
# 102.065
# 99.0082
# 97.6707
# 106.196
# 97.1567
# 101.184
# 100.062
# 100.939
# 105.218
# 96.9413
# 93.9134
# 100.431
# 96.9996
# 104.151
# 96.3908
# 104.368
# 105.03
# 102.866
# 95.9198
# 98.6749
# 102.854
# 91.2726
# 103.603
# 102.371
# 98.2952
# 97.7334
# 90.0228
# 97.6069
# 105.457
# 89.471
# 96.0251
# 107.325
# 102.019
# 105.506
# 103.503
# 91.9119
# 95.3667
# 95.6345
# 102.469
# 91.0941
# 93.5055
# 97.8918
# 102.128
# 102.728
# 103.636
# 89.5254
# 104.418
# 90.9937
# 102.57
# 94.2985
# 102.255
# 87.8358
# 100.193
# 104.451
# 99.3708
# 100.906
# 100.808
# 100.458
# ...

# %%
packets = []  # Initialize an empty list to store delays

for sample in iter(tool):
    packets.append(sample.get_global_packets())

print(len(packets))  # Print the length of delays
# Out:
# 2100

# %%
net = []  # Initialize an empty list to store delays

for sample in iter(tool):
    net.append(sample.get_network_size())

print(len(net))  # Print the length of delays
# Out:
# 2100

# %%
loss = []  # Initialize an empty list to store delays

for sample in iter(tool):
    loss.append(sample.get_global_losses())

print(len(loss))  # Print the length of delays
# Out:
# 2100
